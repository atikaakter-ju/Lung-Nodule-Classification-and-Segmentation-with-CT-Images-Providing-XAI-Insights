# %%
import tensorflow as tf # Imports tensorflow

from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization,Embedding
from tensorflow.keras.layers import Conv2D, MaxPooling2D, ReLU, LSTM,Bidirectional,Attention,Concatenate
from tensorflow.keras import regularizers, optimizers,losses
from tensorflow.keras.metrics import Accuracy,Recall,Precision,AUC,TruePositives,TrueNegatives,FalseNegatives,FalsePositives, SpecificityAtSensitivity,SensitivityAtSpecificity
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.python.keras.utils import np_utils
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns
import sklearn
#import imblearn
#from keras.optimizers import Adam
import matplotlib.pyplot as plt
import time
import os
import sklearn.metrics as m
from glob import glob
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import tree
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import skimage.io
import skimage.color
import skimage.filters
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# # # **Testing The data and Format**

# %%
# Google Drive Mount
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %cd /content/drive/MyDrive/
# %ls
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive
# 'Colab Notebooks'/   Figures/   LungCancer/   Model2.pdf

# %%
images=[]
masks=[]
y=[]
gr_shape=(128,128,1)
img_shape = (128,128,3)
Thres = 1000
input_dir="/content/drive/MyDrive/LungCancer/Datasets/LIDC-IDRI-slices/"
out_dir = "/content/drive/MyDrive/LungCancer/ModelRun"
plt.imshow(img)
plt.show()

# %%
np.asarray(img).shape
# Out:
# (128, 128, 3)

# %%
np.array(images).shape
# Out:
# (0,)

# %%
np.array(masks).shape
# Out:
# (0,)

# %%
images=[]

y=[]
for nodule in os.listdir('/kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001'):
        mask0=[]
        mask1=[]
        mask2=[]
        mask3=[]
        for filename in glob('/kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/'+nodule+'/images/*.png'):
            print(filename)
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            images.append(img)
        for filename in glob('/kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/'+nodule+'/mask-0/*.png'):
            print(filename)
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask0.append(img)
        for filename in glob('/kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/'+nodule+'/mask-1/*.png'):
            print(filename)
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask1.append(img)
        for filename in glob('/kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/'+nodule+'/mask-2/*.png'):
            print(filename)
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask2.append(img)
        for filename in glob('/kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/'+nodule+'/mask-3/*.png'):
            print(filename)
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask3.append(img)
# Out:
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-6.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-7.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-4.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-2.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-8.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-3.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-5.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-0.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/images/slice-1.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-6.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-7.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-4.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-2.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-8.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-3.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-5.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-0.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-0/slice-1.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-6.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-7.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-4.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-2.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-8.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-3.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-5.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-0.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-1/slice-1.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-6.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-7.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-4.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-2.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-8.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-3.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-5.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-0.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-2/slice-1.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-6.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-7.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-4.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-2.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-8.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-3.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-5.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-0.png
# /kaggle/input/lidcidri/LIDC-IDRI-slices/LIDC-IDRI-0001/nodule-0/mask-3/slice-1.png

# %%
i=7
print(mask0[i].sum())
print(mask1[i].sum())
print(mask2[i].sum())
print(mask3[i].sum())
# Out:
# 289935
# 0
# 102510
# 237915

# %%
plt.imshow(mask0[i])
plt.show()
plt.imshow(mask1[i])
plt.show()
plt.imshow(mask2[i])
plt.show()
plt.imshow(mask3[i])
plt.show()

# %%
Thres = 100000

# %%
gmask=[]
for i in range(len(mask0)):
    white_sum=np.array([mask0[i].sum(),mask1[i].sum(),mask2[i].sum(),mask3[i].sum()])
    cnt=int(mask0[i].sum()>Thres)+int(mask1[i].sum()>Thres)+int(mask2[i].sum()>Thres)+int(mask3[i].sum()>Thres)
    print(cnt)
    if(cnt>2):
        print("ID ="+str(white_sum.argmax()))
        print(white_sum)
# Out:
# 4
# ID =0
# [515610 435285 481185 510255]
# 4
# ID =0
# [465885 230265 292995 364905]
# 4
# ID =0
# [694620 639540 635715 672435]
# 4
# ID =0
# [648720 572985 561510 562275]
# 0
# 4
# ID =0
# [710685 688500 684675 681615]
# 4
# ID =0
# [614295 563805 574515 596700]
# 3
# ID =0
# [289935      0 102510 237915]
# 4
# ID =0
# [577575 398565 457470 509490]

# %% [markdown]
# # # **Run From Here**

# %%
gr_shape=(128,128,1)
img_shape = (128,128,3)
input_dir="/kaggle/input/lidcidri/LIDC-IDRI-slices"
images=[]
masks=[]
y=[]
Thres = 1000

# %%
for patient in os.listdir(input_dir):
    for nodule in os.listdir(input_dir+'/'+patient):
        mask0=[]
        mask1=[]
        mask2=[]
        mask3=[]
        for filename in glob(input_dir+'/'+patient+'/'+nodule+'/images/*.png'):
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            images.append(img)
        for filename in glob(input_dir+'/'+patient+'/'+nodule+'/mask-0/*.png'):
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask0.append(img)
        for filename in glob(input_dir+'/'+patient+'/'+nodule+'/mask-1/*.png'):
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask1.append(img)
        for filename in glob(input_dir+'/'+patient+'/'+nodule+'/mask-2/*.png'):
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask2.append(img)
        for filename in glob(input_dir+'/'+patient+'/'+nodule+'/mask-3/*.png'):
            img = image.load_img(filename,target_size=img_shape)
            img = np.asarray(img)
            mask3.append(img)
        for i in range(len(mask0)):
            white_sum=np.array([mask0[i].sum(),mask1[i].sum(),mask2[i].sum(),mask3[i].sum()])
            cnt=int(mask0[i].sum()>Thres)+int(mask1[i].sum()>Thres)+int(mask2[i].sum()>Thres)+int(mask3[i].sum()>Thres)
            if(cnt>2):
                y.append(1)
                if white_sum.argmax()==0:
                    masks.append(mask0[i])
                elif white_sum.argmax()==1:
                    masks.append(mask1[i])
                elif white_sum.argmax()==2:
                    masks.append(mask2[i])
                else:
                    masks.append(mask3[i])
            else:
                y.append(0)
                if white_sum.argmin()==0:
                    masks.append(mask0[i])
                elif white_sum.argmin()==1:
                    masks.append(mask1[i])
                elif white_sum.argmin()==2:
                    masks.append(mask2[i])
                else:
                    masks.append(mask3[i])

# %%
images=np.array(images)
masks=np.array(masks)
label=np.array(y)

# %%
print(images.shape)
print(masks.shape)
print(label.shape)
# Out:
# (31096, 128, 128, 3)
# (31096, 128, 128, 3)
# (31096,)

# %%
yy=pd.DataFrame(label)
yy.value_counts()
# Out:
# 0    15984
# 1    15112
# dtype: int64

# %% [markdown]
# # **Skip from here for transfer learning**

# %%
plt.imshow(images[0])

# %%
plt.imshow(masks[0])

# %%
plt.imshow(images[0]*masks[0])

# %%
def blockred(inp,filters):
    x = Conv2D(filters, 1, activation="relu",padding='same',use_bias=False)(inp)
    x = layers.MaxPooling2D(2)(x)
    x = BatchNormalization(axis=1)(x)

    y = Conv2D(filters,1,activation="relu", padding='same',use_bias=False,)(inp)
    y = Conv2D(filters,3,activation="relu", padding='same',use_bias=False,)(y)
    y = layers.MaxPooling2D(2)(y)
    y = BatchNormalization(axis=1)(y)
    y = Dropout(0.25)(y)
    z = Conv2D(filters, 3, activation="relu", padding='same',use_bias=False)(inp)
    z = layers.MaxPooling2D(2)(z)
    z = BatchNormalization(axis=1)(z)
    output1 = layers.add([x,y,z])
    return output1

# %%
Name = "Seq3cnn"
inputs = keras.Input(shape=img_shape, name="img")
x = layers.Conv2D(32, 3, activation="relu")(inputs)
x = MaxPooling2D(pool_size=(2, 2))(x)
x = BatchNormalization(axis=-1)(x)
x = Dropout(0.25)(x)

y = blockred(x,64)
y = Conv2D(filters=128, kernel_size=(5, 5), activation='relu')(y)
y = Conv2D(filters=128, kernel_size=(3, 3), activation='relu')(y)
y = MaxPooling2D((2,2))(y)
y = BatchNormalization(axis=-1)(y)
y = Dropout(0.25)(y)
y = Conv2D(filters=256, kernel_size=(3, 3), activation='relu')(y)
y = MaxPooling2D((2,2))(y)
y = BatchNormalization(axis=-1)(y)
y = Dropout(0.25)(y)
y = Flatten()(y)
y = Dense(256, activation='relu')(y)
y = Dropout(0.5)(y)
y = Dense(64, activation='sigmoid')(y)
y = Dropout(0.5)(y)
outputs=Dense(1, activation='sigmoid')(y)
model = keras.Model(inputs, outputs, name=Name)
print(model.summary())

# %%
model.compile(optimizer= keras.optimizers.Adam(),  loss=keras.losses.BinaryCrossentropy() , metrics=['acc',Recall(),Precision(),AUC(),TruePositives(),TrueNegatives(),FalseNegatives(),FalsePositives()])
plot_model(model, to_file=Name+'.png',show_shapes= True , show_layer_names=True)
history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), batch_size=64)

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower left')
plt.savefig(Name+'acc.png')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(Name+'loss.png')
plt.show()

model.save(Name+'.h5')
pd.DataFrame.from_dict(history.history).to_csv(Name+'.csv',index=False)

# %% [markdown]
# # # **And From here**

# %%
x_train,x_test,y_train,y_test,mask_train,mask_test = train_test_split(images,label,masks,train_size=0.8, random_state=7)
print(x_train.shape)
print(y_train.shape)
# Out:
# (24876, 128, 128, 3)
# (24876,)

# %%
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.resnet_v2 import ResNet152V2
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.efficientnet import EfficientNetB7
from tensorflow.keras.applications.convnext import ConvNeXtSmall
from tensorflow.keras.applications.convnext import ConvNeXtLarge
from tensorflow.keras.applications.convnext import ConvNeXtBase

# %%
"""
classifier = ResNet152V2(
            include_top = False,input_shape=img_shape,
             weights='imagenet'
           )
fine_tune_at = 100
for layer in classifier.layers[:fine_tune_at]:
    layer.trainable = False

# uncomment here
classifier = EfficientNetB7(
            include_top = False,input_shape=img_shape,
             weights='imagenet'
           )
fine_tune_at = 500
for layer in classifier.layers[:fine_tune_at]:
    layer.trainable = False

# uncomment here

classifier = VGG19(
            include_top = False,input_shape=img_shape,
             weights='imagenet'
           )

fine_tune_at = 20
for layer in classifier.layers[:fine_tune_at]:
    layer.trainable = False

classifier = ConvNeXtSmall(
            include_top = False,input_shape=img_shape,
             weights='imagenet'
           )

fine_tune_at = 100
for layer in classifier.layers[:fine_tune_at]:
    layer.trainable = False
    """
classifier = InceptionV3(
            include_top = False,input_shape=img_shape,
             weights='imagenet'
           )

fine_tune_at = 100
for layer in classifier.layers[:fine_tune_at]:
    layer.trainable = False

# %%
Name='InceptionV3'
model = Sequential()
model.add(classifier)
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.25))
model.add(Dense(32, activation='sigmoid'))
model.add(Dropout(0.25))
model.add(Dense(1, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2, 2, 2048)        21802784
#
#  flatten_6 (Flatten)         (None, 8192)              0
#
#  batch_normalization_664 (Ba  (None, 8192)             32768
#  tchNormalization)
#
#  dense_18 (Dense)            (None, 128)               1048704
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_19 (Dense)            (None, 32)                4128
#
#  dropout_13 (Dropout)        (None, 32)                0
#
#  dense_20 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 22,888,417
# Trainable params: 20,695,617
# Non-trainable params: 2,192,800
# _________________________________________________________________
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping
model.compile (optimizer= keras.optimizers.Adam(),  loss=keras.losses.BinaryCrossentropy() , metrics=['acc',Recall(),Precision(),AUC(),TruePositives(),TrueNegatives(),FalseNegatives(),FalsePositives()])
plot_model(model, to_file=Name+'.png',show_shapes= True , show_layer_names=True)

checkpoint_filepath = 'checkpoint.hdf5'
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_acc',
    mode='max',
    save_best_only=True,
    save_freq=5000)

early_stopping = EarlyStopping(
    monitor='val_acc',
    patience=15,
    min_delta=0.001,
    mode='max',
    restore_best_weights=True
)


history = model.fit(x_train, y_train, epochs=100, validation_data=(x_test, y_test), batch_size=64)

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='lower left')
plt.savefig(Name+'acc.png')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig(Name+'loss.png')
plt.show()



model.save(Name+'.h5')

pd.DataFrame.from_dict(history.history).to_csv(Name+'.csv',index=False)
# Out:
# Epoch 1/100
# 389/389 [==============================] - 62s 96ms/step - loss: 0.0916 - acc: 0.9646 - recall_1: 0.9646 - precision_1: 0.9628 - auc_1: 0.9940 - true_positives_1: 11674.0000 - true_negatives_1: 12322.0000 - false_negatives_1: 429.0000 - false_positives_1: 451.0000 - val_loss: 0.2863 - val_acc: 0.8897 - val_recall_1: 0.8358 - val_precision_1: 0.9291 - val_auc_1: 0.9663 - val_true_positives_1: 2515.0000 - val_true_negatives_1: 3019.0000 - val_false_negatives_1: 494.0000 - val_false_positives_1: 192.0000
# Epoch 2/100
# 389/389 [==============================] - 36s 92ms/step - loss: 0.0985 - acc: 0.9624 - recall_1: 0.9641 - precision_1: 0.9588 - auc_1: 0.9931 - true_positives_1: 11668.0000 - true_negatives_1: 12272.0000 - false_negatives_1: 435.0000 - false_positives_1: 501.0000 - val_loss: 0.1940 - val_acc: 0.9175 - val_recall_1: 0.9352 - val_precision_1: 0.8985 - val_auc_1: 0.9753 - val_true_positives_1: 2814.0000 - val_true_negatives_1: 2893.0000 - val_false_negatives_1: 195.0000 - val_false_positives_1: 318.0000
# Epoch 3/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.0872 - acc: 0.9666 - recall_1: 0.9702 - precision_1: 0.9615 - auc_1: 0.9944 - true_positives_1: 11742.0000 - true_negatives_1: 12303.0000 - false_negatives_1: 361.0000 - false_positives_1: 470.0000 - val_loss: 0.2015 - val_acc: 0.9199 - val_recall_1: 0.8990 - val_precision_1: 0.9331 - val_auc_1: 0.9762 - val_true_positives_1: 2705.0000 - val_true_negatives_1: 3017.0000 - val_false_negatives_1: 304.0000 - val_false_positives_1: 194.0000
# Epoch 4/100
# 389/389 [==============================] - 36s 91ms/step - loss: 0.0846 - acc: 0.9682 - recall_1: 0.9634 - precision_1: 0.9709 - auc_1: 0.9944 - true_positives_1: 11660.0000 - true_negatives_1: 12424.0000 - false_negatives_1: 443.0000 - false_positives_1: 349.0000 - val_loss: 0.1479 - val_acc: 0.9502 - val_recall_1: 0.9405 - val_precision_1: 0.9558 - val_auc_1: 0.9861 - val_true_positives_1: 2830.0000 - val_true_negatives_1: 3080.0000 - val_false_negatives_1: 179.0000 - val_false_positives_1: 131.0000
# Epoch 5/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0788 - acc: 0.9705 - recall_1: 0.9703 - precision_1: 0.9690 - auc_1: 0.9952 - true_positives_1: 11744.0000 - true_negatives_1: 12397.0000 - false_negatives_1: 359.0000 - false_positives_1: 376.0000 - val_loss: 0.1762 - val_acc: 0.9360 - val_recall_1: 0.9329 - val_precision_1: 0.9347 - val_auc_1: 0.9813 - val_true_positives_1: 2807.0000 - val_true_negatives_1: 3015.0000 - val_false_negatives_1: 202.0000 - val_false_positives_1: 196.0000
# Epoch 6/100
# 389/389 [==============================] - 36s 92ms/step - loss: 0.1075 - acc: 0.9604 - recall_1: 0.9603 - precision_1: 0.9584 - auc_1: 0.9918 - true_positives_1: 11623.0000 - true_negatives_1: 12268.0000 - false_negatives_1: 480.0000 - false_positives_1: 505.0000 - val_loss: 0.1744 - val_acc: 0.9338 - val_recall_1: 0.9359 - val_precision_1: 0.9278 - val_auc_1: 0.9812 - val_true_positives_1: 2816.0000 - val_true_negatives_1: 2992.0000 - val_false_negatives_1: 193.0000 - val_false_positives_1: 219.0000
# Epoch 7/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0840 - acc: 0.9689 - recall_1: 0.9713 - precision_1: 0.9650 - auc_1: 0.9945 - true_positives_1: 11756.0000 - true_negatives_1: 12346.0000 - false_negatives_1: 347.0000 - false_positives_1: 427.0000 - val_loss: 0.1603 - val_acc: 0.9473 - val_recall_1: 0.9422 - val_precision_1: 0.9485 - val_auc_1: 0.9843 - val_true_positives_1: 2835.0000 - val_true_negatives_1: 3057.0000 - val_false_negatives_1: 174.0000 - val_false_positives_1: 154.0000
# Epoch 8/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0744 - acc: 0.9726 - recall_1: 0.9756 - precision_1: 0.9683 - auc_1: 0.9955 - true_positives_1: 11808.0000 - true_negatives_1: 12386.0000 - false_negatives_1: 295.0000 - false_positives_1: 387.0000 - val_loss: 0.1709 - val_acc: 0.9431 - val_recall_1: 0.9425 - val_precision_1: 0.9400 - val_auc_1: 0.9812 - val_true_positives_1: 2836.0000 - val_true_negatives_1: 3030.0000 - val_false_negatives_1: 173.0000 - val_false_positives_1: 181.0000
# Epoch 9/100
# 389/389 [==============================] - 36s 92ms/step - loss: 0.0733 - acc: 0.9722 - recall_1: 0.9764 - precision_1: 0.9669 - auc_1: 0.9956 - true_positives_1: 11817.0000 - true_negatives_1: 12368.0000 - false_negatives_1: 286.0000 - false_positives_1: 405.0000 - val_loss: 0.1831 - val_acc: 0.9387 - val_recall_1: 0.9229 - val_precision_1: 0.9491 - val_auc_1: 0.9815 - val_true_positives_1: 2777.0000 - val_true_negatives_1: 3062.0000 - val_false_negatives_1: 232.0000 - val_false_positives_1: 149.0000
# Epoch 10/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0944 - acc: 0.9655 - recall_1: 0.9686 - precision_1: 0.9608 - auc_1: 0.9929 - true_positives_1: 11723.0000 - true_negatives_1: 12295.0000 - false_negatives_1: 380.0000 - false_positives_1: 478.0000 - val_loss: 0.1580 - val_acc: 0.9428 - val_recall_1: 0.9551 - val_precision_1: 0.9286 - val_auc_1: 0.9833 - val_true_positives_1: 2874.0000 - val_true_negatives_1: 2990.0000 - val_false_negatives_1: 135.0000 - val_false_positives_1: 221.0000
# Epoch 11/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.1087 - acc: 0.9576 - recall_1: 0.9613 - precision_1: 0.9520 - auc_1: 0.9916 - true_positives_1: 11635.0000 - true_negatives_1: 12186.0000 - false_negatives_1: 468.0000 - false_positives_1: 587.0000 - val_loss: 0.2252 - val_acc: 0.9262 - val_recall_1: 0.9129 - val_precision_1: 0.9331 - val_auc_1: 0.9689 - val_true_positives_1: 2747.0000 - val_true_negatives_1: 3014.0000 - val_false_negatives_1: 262.0000 - val_false_positives_1: 197.0000
# Epoch 12/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0974 - acc: 0.9654 - recall_1: 0.9686 - precision_1: 0.9606 - auc_1: 0.9929 - true_positives_1: 11723.0000 - true_negatives_1: 12292.0000 - false_negatives_1: 380.0000 - false_positives_1: 481.0000 - val_loss: 0.1784 - val_acc: 0.9373 - val_recall_1: 0.9508 - val_precision_1: 0.9220 - val_auc_1: 0.9812 - val_true_positives_1: 2861.0000 - val_true_negatives_1: 2969.0000 - val_false_negatives_1: 148.0000 - val_false_positives_1: 242.0000
# Epoch 13/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0785 - acc: 0.9702 - recall_1: 0.9755 - precision_1: 0.9636 - auc_1: 0.9951 - true_positives_1: 11807.0000 - true_negatives_1: 12327.0000 - false_negatives_1: 296.0000 - false_positives_1: 446.0000 - val_loss: 0.1567 - val_acc: 0.9477 - val_recall_1: 0.9571 - val_precision_1: 0.9363 - val_auc_1: 0.9845 - val_true_positives_1: 2880.0000 - val_true_negatives_1: 3015.0000 - val_false_negatives_1: 129.0000 - val_false_positives_1: 196.0000
# Epoch 14/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.0658 - acc: 0.9769 - recall_1: 0.9812 - precision_1: 0.9716 - auc_1: 0.9962 - true_positives_1: 11875.0000 - true_negatives_1: 12426.0000 - false_negatives_1: 228.0000 - false_positives_1: 347.0000 - val_loss: 0.1608 - val_acc: 0.9461 - val_recall_1: 0.9601 - val_precision_1: 0.9307 - val_auc_1: 0.9832 - val_true_positives_1: 2889.0000 - val_true_negatives_1: 2996.0000 - val_false_negatives_1: 120.0000 - val_false_positives_1: 215.0000
# Epoch 15/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0679 - acc: 0.9742 - recall_1: 0.9789 - precision_1: 0.9683 - auc_1: 0.9963 - true_positives_1: 11848.0000 - true_negatives_1: 12385.0000 - false_negatives_1: 255.0000 - false_positives_1: 388.0000 - val_loss: 0.1710 - val_acc: 0.9461 - val_recall_1: 0.9611 - val_precision_1: 0.9299 - val_auc_1: 0.9831 - val_true_positives_1: 2892.0000 - val_true_negatives_1: 2993.0000 - val_false_negatives_1: 117.0000 - val_false_positives_1: 218.0000
# Epoch 16/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0719 - acc: 0.9744 - recall_1: 0.9765 - precision_1: 0.9711 - auc_1: 0.9953 - true_positives_1: 11819.0000 - true_negatives_1: 12421.0000 - false_negatives_1: 284.0000 - false_positives_1: 352.0000 - val_loss: 0.1572 - val_acc: 0.9445 - val_recall_1: 0.9405 - val_precision_1: 0.9446 - val_auc_1: 0.9840 - val_true_positives_1: 2830.0000 - val_true_negatives_1: 3045.0000 - val_false_negatives_1: 179.0000 - val_false_positives_1: 166.0000
# Epoch 17/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0784 - acc: 0.9703 - recall_1: 0.9741 - precision_1: 0.9651 - auc_1: 0.9951 - true_positives_1: 11790.0000 - true_negatives_1: 12347.0000 - false_negatives_1: 313.0000 - false_positives_1: 426.0000 - val_loss: 0.1963 - val_acc: 0.9238 - val_recall_1: 0.9585 - val_precision_1: 0.8921 - val_auc_1: 0.9778 - val_true_positives_1: 2884.0000 - val_true_negatives_1: 2862.0000 - val_false_negatives_1: 125.0000 - val_false_positives_1: 349.0000
# Epoch 18/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0716 - acc: 0.9727 - recall_1: 0.9767 - precision_1: 0.9674 - auc_1: 0.9961 - true_positives_1: 11821.0000 - true_negatives_1: 12375.0000 - false_negatives_1: 282.0000 - false_positives_1: 398.0000 - val_loss: 0.2622 - val_acc: 0.8994 - val_recall_1: 0.8468 - val_precision_1: 0.9392 - val_auc_1: 0.9663 - val_true_positives_1: 2548.0000 - val_true_negatives_1: 3046.0000 - val_false_negatives_1: 461.0000 - val_false_positives_1: 165.0000
# Epoch 19/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0998 - acc: 0.9643 - recall_1: 0.9651 - precision_1: 0.9617 - auc_1: 0.9926 - true_positives_1: 11681.0000 - true_negatives_1: 12308.0000 - false_negatives_1: 422.0000 - false_positives_1: 465.0000 - val_loss: 0.1869 - val_acc: 0.9389 - val_recall_1: 0.9302 - val_precision_1: 0.9427 - val_auc_1: 0.9787 - val_true_positives_1: 2799.0000 - val_true_negatives_1: 3041.0000 - val_false_negatives_1: 210.0000 - val_false_positives_1: 170.0000
# Epoch 20/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0996 - acc: 0.9638 - recall_1: 0.9621 - precision_1: 0.9634 - auc_1: 0.9928 - true_positives_1: 11644.0000 - true_negatives_1: 12331.0000 - false_negatives_1: 459.0000 - false_positives_1: 442.0000 - val_loss: 0.1584 - val_acc: 0.9469 - val_recall_1: 0.9295 - val_precision_1: 0.9595 - val_auc_1: 0.9843 - val_true_positives_1: 2797.0000 - val_true_negatives_1: 3093.0000 - val_false_negatives_1: 212.0000 - val_false_positives_1: 118.0000
# Epoch 21/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0747 - acc: 0.9717 - recall_1: 0.9724 - precision_1: 0.9694 - auc_1: 0.9956 - true_positives_1: 11769.0000 - true_negatives_1: 12402.0000 - false_negatives_1: 334.0000 - false_positives_1: 371.0000 - val_loss: 0.1734 - val_acc: 0.9436 - val_recall_1: 0.9624 - val_precision_1: 0.9241 - val_auc_1: 0.9821 - val_true_positives_1: 2896.0000 - val_true_negatives_1: 2973.0000 - val_false_negatives_1: 113.0000 - val_false_positives_1: 238.0000
# Epoch 22/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0674 - acc: 0.9759 - recall_1: 0.9763 - precision_1: 0.9743 - auc_1: 0.9962 - true_positives_1: 11816.0000 - true_negatives_1: 12461.0000 - false_negatives_1: 287.0000 - false_positives_1: 312.0000 - val_loss: 0.1462 - val_acc: 0.9476 - val_recall_1: 0.9315 - val_precision_1: 0.9589 - val_auc_1: 0.9849 - val_true_positives_1: 2803.0000 - val_true_negatives_1: 3091.0000 - val_false_negatives_1: 206.0000 - val_false_positives_1: 120.0000
# Epoch 23/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0587 - acc: 0.9795 - recall_1: 0.9796 - precision_1: 0.9784 - auc_1: 0.9967 - true_positives_1: 11856.0000 - true_negatives_1: 12511.0000 - false_negatives_1: 247.0000 - false_positives_1: 262.0000 - val_loss: 0.1379 - val_acc: 0.9566 - val_recall_1: 0.9641 - val_precision_1: 0.9471 - val_auc_1: 0.9868 - val_true_positives_1: 2901.0000 - val_true_negatives_1: 3049.0000 - val_false_negatives_1: 108.0000 - val_false_positives_1: 162.0000
# Epoch 24/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0702 - acc: 0.9756 - recall_1: 0.9732 - precision_1: 0.9765 - auc_1: 0.9954 - true_positives_1: 11779.0000 - true_negatives_1: 12489.0000 - false_negatives_1: 324.0000 - false_positives_1: 284.0000 - val_loss: 0.1508 - val_acc: 0.9529 - val_recall_1: 0.9565 - val_precision_1: 0.9467 - val_auc_1: 0.9851 - val_true_positives_1: 2878.0000 - val_true_negatives_1: 3049.0000 - val_false_negatives_1: 131.0000 - val_false_positives_1: 162.0000
# Epoch 25/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0738 - acc: 0.9734 - recall_1: 0.9735 - precision_1: 0.9720 - auc_1: 0.9955 - true_positives_1: 11782.0000 - true_negatives_1: 12433.0000 - false_negatives_1: 321.0000 - false_positives_1: 340.0000 - val_loss: 0.1529 - val_acc: 0.9531 - val_recall_1: 0.9508 - val_precision_1: 0.9521 - val_auc_1: 0.9830 - val_true_positives_1: 2861.0000 - val_true_negatives_1: 3067.0000 - val_false_negatives_1: 148.0000 - val_false_positives_1: 144.0000
# Epoch 26/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0732 - acc: 0.9739 - recall_1: 0.9723 - precision_1: 0.9740 - auc_1: 0.9949 - true_positives_1: 11768.0000 - true_negatives_1: 12459.0000 - false_negatives_1: 335.0000 - false_positives_1: 314.0000 - val_loss: 0.1671 - val_acc: 0.9486 - val_recall_1: 0.9601 - val_precision_1: 0.9353 - val_auc_1: 0.9846 - val_true_positives_1: 2889.0000 - val_true_negatives_1: 3011.0000 - val_false_negatives_1: 120.0000 - val_false_positives_1: 200.0000
# Epoch 27/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0763 - acc: 0.9718 - recall_1: 0.9737 - precision_1: 0.9685 - auc_1: 0.9950 - true_positives_1: 11785.0000 - true_negatives_1: 12390.0000 - false_negatives_1: 318.0000 - false_positives_1: 383.0000 - val_loss: 0.1676 - val_acc: 0.9473 - val_recall_1: 0.9445 - val_precision_1: 0.9464 - val_auc_1: 0.9822 - val_true_positives_1: 2842.0000 - val_true_negatives_1: 3050.0000 - val_false_negatives_1: 167.0000 - val_false_positives_1: 161.0000
# Epoch 28/100
# 389/389 [==============================] - 36s 91ms/step - loss: 0.0782 - acc: 0.9723 - recall_1: 0.9743 - precision_1: 0.9689 - auc_1: 0.9950 - true_positives_1: 11792.0000 - true_negatives_1: 12394.0000 - false_negatives_1: 311.0000 - false_positives_1: 379.0000 - val_loss: 0.1555 - val_acc: 0.9481 - val_recall_1: 0.9392 - val_precision_1: 0.9528 - val_auc_1: 0.9840 - val_true_positives_1: 2826.0000 - val_true_negatives_1: 3071.0000 - val_false_negatives_1: 183.0000 - val_false_positives_1: 140.0000
# Epoch 29/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0803 - acc: 0.9712 - recall_1: 0.9711 - precision_1: 0.9698 - auc_1: 0.9947 - true_positives_1: 11753.0000 - true_negatives_1: 12407.0000 - false_negatives_1: 350.0000 - false_positives_1: 366.0000 - val_loss: 0.1867 - val_acc: 0.9367 - val_recall_1: 0.9172 - val_precision_1: 0.9501 - val_auc_1: 0.9795 - val_true_positives_1: 2760.0000 - val_true_negatives_1: 3066.0000 - val_false_negatives_1: 249.0000 - val_false_positives_1: 145.0000
# Epoch 30/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.0776 - acc: 0.9719 - recall_1: 0.9725 - precision_1: 0.9699 - auc_1: 0.9950 - true_positives_1: 11770.0000 - true_negatives_1: 12408.0000 - false_negatives_1: 333.0000 - false_positives_1: 365.0000 - val_loss: 0.1591 - val_acc: 0.9477 - val_recall_1: 0.9495 - val_precision_1: 0.9429 - val_auc_1: 0.9831 - val_true_positives_1: 2857.0000 - val_true_negatives_1: 3038.0000 - val_false_negatives_1: 152.0000 - val_false_positives_1: 173.0000
# Epoch 31/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0761 - acc: 0.9734 - recall_1: 0.9742 - precision_1: 0.9712 - auc_1: 0.9947 - true_positives_1: 11791.0000 - true_negatives_1: 12423.0000 - false_negatives_1: 312.0000 - false_positives_1: 350.0000 - val_loss: 0.1686 - val_acc: 0.9486 - val_recall_1: 0.9521 - val_precision_1: 0.9421 - val_auc_1: 0.9821 - val_true_positives_1: 2865.0000 - val_true_negatives_1: 3035.0000 - val_false_negatives_1: 144.0000 - val_false_positives_1: 176.0000
# Epoch 32/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0986 - acc: 0.9656 - recall_1: 0.9703 - precision_1: 0.9595 - auc_1: 0.9921 - true_positives_1: 11743.0000 - true_negatives_1: 12277.0000 - false_negatives_1: 360.0000 - false_positives_1: 496.0000 - val_loss: 0.2032 - val_acc: 0.9317 - val_recall_1: 0.9176 - val_precision_1: 0.9398 - val_auc_1: 0.9762 - val_true_positives_1: 2761.0000 - val_true_negatives_1: 3034.0000 - val_false_negatives_1: 248.0000 - val_false_positives_1: 177.0000
# Epoch 33/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0919 - acc: 0.9671 - recall_1: 0.9762 - precision_1: 0.9571 - auc_1: 0.9932 - true_positives_1: 11815.0000 - true_negatives_1: 12243.0000 - false_negatives_1: 288.0000 - false_positives_1: 530.0000 - val_loss: 0.1657 - val_acc: 0.9489 - val_recall_1: 0.9551 - val_precision_1: 0.9401 - val_auc_1: 0.9804 - val_true_positives_1: 2874.0000 - val_true_negatives_1: 3028.0000 - val_false_negatives_1: 135.0000 - val_false_positives_1: 183.0000
# Epoch 34/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0832 - acc: 0.9705 - recall_1: 0.9711 - precision_1: 0.9683 - auc_1: 0.9944 - true_positives_1: 11753.0000 - true_negatives_1: 12388.0000 - false_negatives_1: 350.0000 - false_positives_1: 385.0000 - val_loss: 0.1961 - val_acc: 0.9416 - val_recall_1: 0.9385 - val_precision_1: 0.9407 - val_auc_1: 0.9770 - val_true_positives_1: 2824.0000 - val_true_negatives_1: 3033.0000 - val_false_negatives_1: 185.0000 - val_false_positives_1: 178.0000
# Epoch 35/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0756 - acc: 0.9748 - recall_1: 0.9753 - precision_1: 0.9730 - auc_1: 0.9951 - true_positives_1: 11804.0000 - true_negatives_1: 12445.0000 - false_negatives_1: 299.0000 - false_positives_1: 328.0000 - val_loss: 0.1572 - val_acc: 0.9516 - val_recall_1: 0.9541 - val_precision_1: 0.9463 - val_auc_1: 0.9812 - val_true_positives_1: 2871.0000 - val_true_negatives_1: 3048.0000 - val_false_negatives_1: 138.0000 - val_false_positives_1: 163.0000
# Epoch 36/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0788 - acc: 0.9734 - recall_1: 0.9717 - precision_1: 0.9736 - auc_1: 0.9948 - true_positives_1: 11761.0000 - true_negatives_1: 12454.0000 - false_negatives_1: 342.0000 - false_positives_1: 319.0000 - val_loss: 0.1392 - val_acc: 0.9513 - val_recall_1: 0.9392 - val_precision_1: 0.9593 - val_auc_1: 0.9862 - val_true_positives_1: 2826.0000 - val_true_negatives_1: 3091.0000 - val_false_negatives_1: 183.0000 - val_false_positives_1: 120.0000
# Epoch 37/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0615 - acc: 0.9794 - recall_1: 0.9813 - precision_1: 0.9764 - auc_1: 0.9965 - true_positives_1: 11877.0000 - true_negatives_1: 12486.0000 - false_negatives_1: 226.0000 - false_positives_1: 287.0000 - val_loss: 0.1688 - val_acc: 0.9410 - val_recall_1: 0.9126 - val_precision_1: 0.9635 - val_auc_1: 0.9845 - val_true_positives_1: 2746.0000 - val_true_negatives_1: 3107.0000 - val_false_negatives_1: 263.0000 - val_false_positives_1: 104.0000
# Epoch 38/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0688 - acc: 0.9759 - recall_1: 0.9744 - precision_1: 0.9760 - auc_1: 0.9958 - true_positives_1: 11793.0000 - true_negatives_1: 12483.0000 - false_negatives_1: 310.0000 - false_positives_1: 290.0000 - val_loss: 0.1969 - val_acc: 0.9275 - val_recall_1: 0.9069 - val_precision_1: 0.9410 - val_auc_1: 0.9770 - val_true_positives_1: 2729.0000 - val_true_negatives_1: 3040.0000 - val_false_negatives_1: 280.0000 - val_false_positives_1: 171.0000
# Epoch 39/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0850 - acc: 0.9713 - recall_1: 0.9698 - precision_1: 0.9711 - auc_1: 0.9942 - true_positives_1: 11738.0000 - true_negatives_1: 12424.0000 - false_negatives_1: 365.0000 - false_positives_1: 349.0000 - val_loss: 0.1687 - val_acc: 0.9341 - val_recall_1: 0.9033 - val_precision_1: 0.9581 - val_auc_1: 0.9831 - val_true_positives_1: 2718.0000 - val_true_negatives_1: 3092.0000 - val_false_negatives_1: 291.0000 - val_false_positives_1: 119.0000
# Epoch 40/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0721 - acc: 0.9759 - recall_1: 0.9760 - precision_1: 0.9746 - auc_1: 0.9952 - true_positives_1: 11812.0000 - true_negatives_1: 12465.0000 - false_negatives_1: 291.0000 - false_positives_1: 308.0000 - val_loss: 0.1478 - val_acc: 0.9521 - val_recall_1: 0.9375 - val_precision_1: 0.9625 - val_auc_1: 0.9845 - val_true_positives_1: 2821.0000 - val_true_negatives_1: 3101.0000 - val_false_negatives_1: 188.0000 - val_false_positives_1: 110.0000
# Epoch 41/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0743 - acc: 0.9758 - recall_1: 0.9760 - precision_1: 0.9743 - auc_1: 0.9952 - true_positives_1: 11812.0000 - true_negatives_1: 12461.0000 - false_negatives_1: 291.0000 - false_positives_1: 312.0000 - val_loss: 0.1558 - val_acc: 0.9516 - val_recall_1: 0.9575 - val_precision_1: 0.9434 - val_auc_1: 0.9849 - val_true_positives_1: 2881.0000 - val_true_negatives_1: 3038.0000 - val_false_negatives_1: 128.0000 - val_false_positives_1: 173.0000
# Epoch 42/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.0881 - acc: 0.9729 - recall_1: 0.9812 - precision_1: 0.9638 - auc_1: 0.9925 - true_positives_1: 11876.0000 - true_negatives_1: 12327.0000 - false_negatives_1: 227.0000 - false_positives_1: 446.0000 - val_loss: 0.1857 - val_acc: 0.9365 - val_recall_1: 0.9016 - val_precision_1: 0.9648 - val_auc_1: 0.9783 - val_true_positives_1: 2713.0000 - val_true_negatives_1: 3112.0000 - val_false_negatives_1: 296.0000 - val_false_positives_1: 99.0000
# Epoch 43/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0884 - acc: 0.9708 - recall_1: 0.9725 - precision_1: 0.9677 - auc_1: 0.9930 - true_positives_1: 11770.0000 - true_negatives_1: 12380.0000 - false_negatives_1: 333.0000 - false_positives_1: 393.0000 - val_loss: 0.1740 - val_acc: 0.9449 - val_recall_1: 0.9428 - val_precision_1: 0.9432 - val_auc_1: 0.9797 - val_true_positives_1: 2837.0000 - val_true_negatives_1: 3040.0000 - val_false_negatives_1: 172.0000 - val_false_positives_1: 171.0000
# Epoch 44/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0857 - acc: 0.9727 - recall_1: 0.9736 - precision_1: 0.9704 - auc_1: 0.9934 - true_positives_1: 11784.0000 - true_negatives_1: 12414.0000 - false_negatives_1: 319.0000 - false_positives_1: 359.0000 - val_loss: 0.1657 - val_acc: 0.9432 - val_recall_1: 0.9671 - val_precision_1: 0.9197 - val_auc_1: 0.9822 - val_true_positives_1: 2910.0000 - val_true_negatives_1: 2957.0000 - val_false_negatives_1: 99.0000 - val_false_positives_1: 254.0000
# Epoch 45/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0758 - acc: 0.9749 - recall_1: 0.9778 - precision_1: 0.9708 - auc_1: 0.9946 - true_positives_1: 11834.0000 - true_negatives_1: 12417.0000 - false_negatives_1: 269.0000 - false_positives_1: 356.0000 - val_loss: 0.1546 - val_acc: 0.9535 - val_recall_1: 0.9545 - val_precision_1: 0.9497 - val_auc_1: 0.9836 - val_true_positives_1: 2872.0000 - val_true_negatives_1: 3059.0000 - val_false_negatives_1: 137.0000 - val_false_positives_1: 152.0000
# Epoch 46/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0981 - acc: 0.9680 - recall_1: 0.9674 - precision_1: 0.9669 - auc_1: 0.9914 - true_positives_1: 11708.0000 - true_negatives_1: 12372.0000 - false_negatives_1: 395.0000 - false_positives_1: 401.0000 - val_loss: 0.2368 - val_acc: 0.9093 - val_recall_1: 0.8764 - val_precision_1: 0.9321 - val_auc_1: 0.9658 - val_true_positives_1: 2637.0000 - val_true_negatives_1: 3019.0000 - val_false_negatives_1: 372.0000 - val_false_positives_1: 192.0000
# Epoch 47/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0975 - acc: 0.9681 - recall_1: 0.9692 - precision_1: 0.9654 - auc_1: 0.9917 - true_positives_1: 11730.0000 - true_negatives_1: 12353.0000 - false_negatives_1: 373.0000 - false_positives_1: 420.0000 - val_loss: 0.1913 - val_acc: 0.9363 - val_recall_1: 0.9276 - val_precision_1: 0.9400 - val_auc_1: 0.9773 - val_true_positives_1: 2791.0000 - val_true_negatives_1: 3033.0000 - val_false_negatives_1: 218.0000 - val_false_positives_1: 178.0000
# Epoch 48/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0891 - acc: 0.9702 - recall_1: 0.9716 - precision_1: 0.9673 - auc_1: 0.9929 - true_positives_1: 11759.0000 - true_negatives_1: 12376.0000 - false_negatives_1: 344.0000 - false_positives_1: 397.0000 - val_loss: 0.2059 - val_acc: 0.9243 - val_recall_1: 0.9585 - val_precision_1: 0.8929 - val_auc_1: 0.9750 - val_true_positives_1: 2884.0000 - val_true_negatives_1: 2865.0000 - val_false_negatives_1: 125.0000 - val_false_positives_1: 346.0000
# Epoch 49/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0901 - acc: 0.9700 - recall_1: 0.9665 - precision_1: 0.9717 - auc_1: 0.9927 - true_positives_1: 11697.0000 - true_negatives_1: 12432.0000 - false_negatives_1: 406.0000 - false_positives_1: 341.0000 - val_loss: 0.1619 - val_acc: 0.9495 - val_recall_1: 0.9508 - val_precision_1: 0.9452 - val_auc_1: 0.9826 - val_true_positives_1: 2861.0000 - val_true_negatives_1: 3045.0000 - val_false_negatives_1: 148.0000 - val_false_positives_1: 166.0000
# Epoch 50/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0680 - acc: 0.9796 - recall_1: 0.9812 - precision_1: 0.9770 - auc_1: 0.9947 - true_positives_1: 11876.0000 - true_negatives_1: 12493.0000 - false_negatives_1: 227.0000 - false_positives_1: 280.0000 - val_loss: 0.1576 - val_acc: 0.9564 - val_recall_1: 0.9628 - val_precision_1: 0.9480 - val_auc_1: 0.9824 - val_true_positives_1: 2897.0000 - val_true_negatives_1: 3052.0000 - val_false_negatives_1: 112.0000 - val_false_positives_1: 159.0000
# Epoch 51/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0617 - acc: 0.9807 - recall_1: 0.9815 - precision_1: 0.9788 - auc_1: 0.9958 - true_positives_1: 11879.0000 - true_negatives_1: 12516.0000 - false_negatives_1: 224.0000 - false_positives_1: 257.0000 - val_loss: 0.1608 - val_acc: 0.9428 - val_recall_1: 0.9674 - val_precision_1: 0.9186 - val_auc_1: 0.9833 - val_true_positives_1: 2911.0000 - val_true_negatives_1: 2953.0000 - val_false_negatives_1: 98.0000 - val_false_positives_1: 258.0000
# Epoch 52/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0611 - acc: 0.9818 - recall_1: 0.9849 - precision_1: 0.9779 - auc_1: 0.9956 - true_positives_1: 11920.0000 - true_negatives_1: 12503.0000 - false_negatives_1: 183.0000 - false_positives_1: 270.0000 - val_loss: 0.1677 - val_acc: 0.9481 - val_recall_1: 0.9295 - val_precision_1: 0.9618 - val_auc_1: 0.9826 - val_true_positives_1: 2797.0000 - val_true_negatives_1: 3100.0000 - val_false_negatives_1: 212.0000 - val_false_positives_1: 111.0000
# Epoch 53/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0608 - acc: 0.9809 - recall_1: 0.9802 - precision_1: 0.9806 - auc_1: 0.9961 - true_positives_1: 11863.0000 - true_negatives_1: 12538.0000 - false_negatives_1: 240.0000 - false_positives_1: 235.0000 - val_loss: 0.1464 - val_acc: 0.9574 - val_recall_1: 0.9601 - val_precision_1: 0.9522 - val_auc_1: 0.9853 - val_true_positives_1: 2889.0000 - val_true_negatives_1: 3066.0000 - val_false_negatives_1: 120.0000 - val_false_positives_1: 145.0000
# Epoch 54/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0654 - acc: 0.9797 - recall_1: 0.9814 - precision_1: 0.9769 - auc_1: 0.9955 - true_positives_1: 11878.0000 - true_negatives_1: 12492.0000 - false_negatives_1: 225.0000 - false_positives_1: 281.0000 - val_loss: 0.1665 - val_acc: 0.9503 - val_recall_1: 0.9472 - val_precision_1: 0.9500 - val_auc_1: 0.9835 - val_true_positives_1: 2850.0000 - val_true_negatives_1: 3061.0000 - val_false_negatives_1: 159.0000 - val_false_positives_1: 150.0000
# Epoch 55/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0833 - acc: 0.9734 - recall_1: 0.9723 - precision_1: 0.9730 - auc_1: 0.9939 - true_positives_1: 11768.0000 - true_negatives_1: 12447.0000 - false_negatives_1: 335.0000 - false_positives_1: 326.0000 - val_loss: 0.1609 - val_acc: 0.9511 - val_recall_1: 0.9538 - val_precision_1: 0.9456 - val_auc_1: 0.9835 - val_true_positives_1: 2870.0000 - val_true_negatives_1: 3046.0000 - val_false_negatives_1: 139.0000 - val_false_positives_1: 165.0000
# Epoch 56/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0687 - acc: 0.9785 - recall_1: 0.9790 - precision_1: 0.9768 - auc_1: 0.9954 - true_positives_1: 11849.0000 - true_negatives_1: 12491.0000 - false_negatives_1: 254.0000 - false_positives_1: 282.0000 - val_loss: 0.1701 - val_acc: 0.9449 - val_recall_1: 0.9365 - val_precision_1: 0.9488 - val_auc_1: 0.9825 - val_true_positives_1: 2818.0000 - val_true_negatives_1: 3059.0000 - val_false_negatives_1: 191.0000 - val_false_positives_1: 152.0000
# Epoch 57/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0917 - acc: 0.9721 - recall_1: 0.9729 - precision_1: 0.9699 - auc_1: 0.9927 - true_positives_1: 11775.0000 - true_negatives_1: 12408.0000 - false_negatives_1: 328.0000 - false_positives_1: 365.0000 - val_loss: 0.2442 - val_acc: 0.9095 - val_recall_1: 0.8488 - val_precision_1: 0.9594 - val_auc_1: 0.9669 - val_true_positives_1: 2554.0000 - val_true_negatives_1: 3103.0000 - val_false_negatives_1: 455.0000 - val_false_positives_1: 108.0000
# Epoch 58/100
# 389/389 [==============================] - 36s 91ms/step - loss: 0.0923 - acc: 0.9691 - recall_1: 0.9636 - precision_1: 0.9726 - auc_1: 0.9930 - true_positives_1: 11662.0000 - true_negatives_1: 12445.0000 - false_negatives_1: 441.0000 - false_positives_1: 328.0000 - val_loss: 0.1870 - val_acc: 0.9256 - val_recall_1: 0.9528 - val_precision_1: 0.8993 - val_auc_1: 0.9791 - val_true_positives_1: 2867.0000 - val_true_negatives_1: 2890.0000 - val_false_negatives_1: 142.0000 - val_false_positives_1: 321.0000
# Epoch 59/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0862 - acc: 0.9724 - recall_1: 0.9692 - precision_1: 0.9740 - auc_1: 0.9940 - true_positives_1: 11730.0000 - true_negatives_1: 12460.0000 - false_negatives_1: 373.0000 - false_positives_1: 313.0000 - val_loss: 0.1526 - val_acc: 0.9513 - val_recall_1: 0.9322 - val_precision_1: 0.9659 - val_auc_1: 0.9851 - val_true_positives_1: 2805.0000 - val_true_negatives_1: 3112.0000 - val_false_negatives_1: 204.0000 - val_false_positives_1: 99.0000
# Epoch 60/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0696 - acc: 0.9774 - recall_1: 0.9765 - precision_1: 0.9771 - auc_1: 0.9953 - true_positives_1: 11819.0000 - true_negatives_1: 12496.0000 - false_negatives_1: 284.0000 - false_positives_1: 277.0000 - val_loss: 0.1539 - val_acc: 0.9461 - val_recall_1: 0.9209 - val_precision_1: 0.9662 - val_auc_1: 0.9861 - val_true_positives_1: 2771.0000 - val_true_negatives_1: 3114.0000 - val_false_negatives_1: 238.0000 - val_false_positives_1: 97.0000
# Epoch 61/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0570 - acc: 0.9815 - recall_1: 0.9823 - precision_1: 0.9798 - auc_1: 0.9967 - true_positives_1: 11889.0000 - true_negatives_1: 12528.0000 - false_negatives_1: 214.0000 - false_positives_1: 245.0000 - val_loss: 0.1602 - val_acc: 0.9497 - val_recall_1: 0.9448 - val_precision_1: 0.9508 - val_auc_1: 0.9836 - val_true_positives_1: 2843.0000 - val_true_negatives_1: 3064.0000 - val_false_negatives_1: 166.0000 - val_false_positives_1: 147.0000
# Epoch 62/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.1098 - acc: 0.9624 - recall_1: 0.9574 - precision_1: 0.9650 - auc_1: 0.9911 - true_positives_1: 11588.0000 - true_negatives_1: 12353.0000 - false_negatives_1: 515.0000 - false_positives_1: 420.0000 - val_loss: 0.1749 - val_acc: 0.9474 - val_recall_1: 0.9259 - val_precision_1: 0.9640 - val_auc_1: 0.9816 - val_true_positives_1: 2786.0000 - val_true_negatives_1: 3107.0000 - val_false_negatives_1: 223.0000 - val_false_positives_1: 104.0000
# Epoch 63/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0686 - acc: 0.9762 - recall_1: 0.9754 - precision_1: 0.9756 - auc_1: 0.9958 - true_positives_1: 11805.0000 - true_negatives_1: 12478.0000 - false_negatives_1: 298.0000 - false_positives_1: 295.0000 - val_loss: 0.2187 - val_acc: 0.9305 - val_recall_1: 0.9535 - val_precision_1: 0.9076 - val_auc_1: 0.9756 - val_true_positives_1: 2869.0000 - val_true_negatives_1: 2919.0000 - val_false_negatives_1: 140.0000 - val_false_positives_1: 292.0000
# Epoch 64/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0855 - acc: 0.9709 - recall_1: 0.9675 - precision_1: 0.9726 - auc_1: 0.9939 - true_positives_1: 11710.0000 - true_negatives_1: 12443.0000 - false_negatives_1: 393.0000 - false_positives_1: 330.0000 - val_loss: 0.1844 - val_acc: 0.9415 - val_recall_1: 0.9269 - val_precision_1: 0.9509 - val_auc_1: 0.9794 - val_true_positives_1: 2789.0000 - val_true_negatives_1: 3067.0000 - val_false_negatives_1: 220.0000 - val_false_positives_1: 144.0000
# Epoch 65/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0796 - acc: 0.9751 - recall_1: 0.9730 - precision_1: 0.9758 - auc_1: 0.9941 - true_positives_1: 11776.0000 - true_negatives_1: 12481.0000 - false_negatives_1: 327.0000 - false_positives_1: 292.0000 - val_loss: 0.1618 - val_acc: 0.9537 - val_recall_1: 0.9585 - val_precision_1: 0.9465 - val_auc_1: 0.9826 - val_true_positives_1: 2884.0000 - val_true_negatives_1: 3048.0000 - val_false_negatives_1: 125.0000 - val_false_positives_1: 163.0000
# Epoch 66/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0783 - acc: 0.9759 - recall_1: 0.9757 - precision_1: 0.9747 - auc_1: 0.9942 - true_positives_1: 11809.0000 - true_negatives_1: 12467.0000 - false_negatives_1: 294.0000 - false_positives_1: 306.0000 - val_loss: 0.2148 - val_acc: 0.9256 - val_recall_1: 0.9020 - val_precision_1: 0.9417 - val_auc_1: 0.9753 - val_true_positives_1: 2714.0000 - val_true_negatives_1: 3043.0000 - val_false_negatives_1: 295.0000 - val_false_positives_1: 168.0000
# Epoch 67/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0972 - acc: 0.9676 - recall_1: 0.9679 - precision_1: 0.9656 - auc_1: 0.9930 - true_positives_1: 11715.0000 - true_negatives_1: 12356.0000 - false_negatives_1: 388.0000 - false_positives_1: 417.0000 - val_loss: 0.1741 - val_acc: 0.9381 - val_recall_1: 0.9359 - val_precision_1: 0.9362 - val_auc_1: 0.9810 - val_true_positives_1: 2816.0000 - val_true_negatives_1: 3019.0000 - val_false_negatives_1: 193.0000 - val_false_positives_1: 192.0000
# Epoch 68/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0879 - acc: 0.9707 - recall_1: 0.9673 - precision_1: 0.9723 - auc_1: 0.9938 - true_positives_1: 11707.0000 - true_negatives_1: 12439.0000 - false_negatives_1: 396.0000 - false_positives_1: 334.0000 - val_loss: 0.1678 - val_acc: 0.9415 - val_recall_1: 0.9472 - val_precision_1: 0.9329 - val_auc_1: 0.9820 - val_true_positives_1: 2850.0000 - val_true_negatives_1: 3006.0000 - val_false_negatives_1: 159.0000 - val_false_positives_1: 205.0000
# Epoch 69/100
# 389/389 [==============================] - 36s 91ms/step - loss: 0.0831 - acc: 0.9727 - recall_1: 0.9684 - precision_1: 0.9752 - auc_1: 0.9945 - true_positives_1: 11721.0000 - true_negatives_1: 12475.0000 - false_negatives_1: 382.0000 - false_positives_1: 298.0000 - val_loss: 0.1681 - val_acc: 0.9397 - val_recall_1: 0.9106 - val_precision_1: 0.9628 - val_auc_1: 0.9839 - val_true_positives_1: 2740.0000 - val_true_negatives_1: 3105.0000 - val_false_negatives_1: 269.0000 - val_false_positives_1: 106.0000
# Epoch 70/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0766 - acc: 0.9744 - recall_1: 0.9701 - precision_1: 0.9772 - auc_1: 0.9949 - true_positives_1: 11741.0000 - true_negatives_1: 12499.0000 - false_negatives_1: 362.0000 - false_positives_1: 274.0000 - val_loss: 0.1740 - val_acc: 0.9441 - val_recall_1: 0.9239 - val_precision_1: 0.9590 - val_auc_1: 0.9815 - val_true_positives_1: 2780.0000 - val_true_negatives_1: 3092.0000 - val_false_negatives_1: 229.0000 - val_false_positives_1: 119.0000
# Epoch 71/100
# 389/389 [==============================] - 36s 91ms/step - loss: 0.0940 - acc: 0.9693 - recall_1: 0.9707 - precision_1: 0.9664 - auc_1: 0.9928 - true_positives_1: 11748.0000 - true_negatives_1: 12365.0000 - false_negatives_1: 355.0000 - false_positives_1: 408.0000 - val_loss: 0.1625 - val_acc: 0.9521 - val_recall_1: 0.9488 - val_precision_1: 0.9520 - val_auc_1: 0.9832 - val_true_positives_1: 2855.0000 - val_true_negatives_1: 3067.0000 - val_false_negatives_1: 154.0000 - val_false_positives_1: 144.0000
# Epoch 72/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.0760 - acc: 0.9771 - recall_1: 0.9770 - precision_1: 0.9760 - auc_1: 0.9945 - true_positives_1: 11825.0000 - true_negatives_1: 12482.0000 - false_negatives_1: 278.0000 - false_positives_1: 291.0000 - val_loss: 0.1557 - val_acc: 0.9535 - val_recall_1: 0.9501 - val_precision_1: 0.9536 - val_auc_1: 0.9832 - val_true_positives_1: 2859.0000 - val_true_negatives_1: 3072.0000 - val_false_negatives_1: 150.0000 - val_false_positives_1: 139.0000
# Epoch 73/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0812 - acc: 0.9734 - recall_1: 0.9719 - precision_1: 0.9734 - auc_1: 0.9942 - true_positives_1: 11763.0000 - true_negatives_1: 12452.0000 - false_negatives_1: 340.0000 - false_positives_1: 321.0000 - val_loss: 0.1583 - val_acc: 0.9492 - val_recall_1: 0.9452 - val_precision_1: 0.9496 - val_auc_1: 0.9840 - val_true_positives_1: 2844.0000 - val_true_negatives_1: 3060.0000 - val_false_negatives_1: 165.0000 - val_false_positives_1: 151.0000
# Epoch 74/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0855 - acc: 0.9715 - recall_1: 0.9670 - precision_1: 0.9741 - auc_1: 0.9940 - true_positives_1: 11704.0000 - true_negatives_1: 12462.0000 - false_negatives_1: 399.0000 - false_positives_1: 311.0000 - val_loss: 0.1893 - val_acc: 0.9365 - val_recall_1: 0.9123 - val_precision_1: 0.9545 - val_auc_1: 0.9787 - val_true_positives_1: 2745.0000 - val_true_negatives_1: 3080.0000 - val_false_negatives_1: 264.0000 - val_false_positives_1: 131.0000
# Epoch 75/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0808 - acc: 0.9732 - recall_1: 0.9724 - precision_1: 0.9726 - auc_1: 0.9947 - true_positives_1: 11769.0000 - true_negatives_1: 12441.0000 - false_negatives_1: 334.0000 - false_positives_1: 332.0000 - val_loss: 0.1847 - val_acc: 0.9389 - val_recall_1: 0.9272 - val_precision_1: 0.9454 - val_auc_1: 0.9800 - val_true_positives_1: 2790.0000 - val_true_negatives_1: 3050.0000 - val_false_negatives_1: 219.0000 - val_false_positives_1: 161.0000
# Epoch 76/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0901 - acc: 0.9697 - recall_1: 0.9769 - precision_1: 0.9614 - auc_1: 0.9938 - true_positives_1: 11824.0000 - true_negatives_1: 12298.0000 - false_negatives_1: 279.0000 - false_positives_1: 475.0000 - val_loss: 0.1642 - val_acc: 0.9426 - val_recall_1: 0.9668 - val_precision_1: 0.9188 - val_auc_1: 0.9841 - val_true_positives_1: 2909.0000 - val_true_negatives_1: 2954.0000 - val_false_negatives_1: 100.0000 - val_false_positives_1: 257.0000
# Epoch 77/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0809 - acc: 0.9748 - recall_1: 0.9822 - precision_1: 0.9667 - auc_1: 0.9942 - true_positives_1: 11887.0000 - true_negatives_1: 12363.0000 - false_negatives_1: 216.0000 - false_positives_1: 410.0000 - val_loss: 0.1431 - val_acc: 0.9495 - val_recall_1: 0.9385 - val_precision_1: 0.9563 - val_auc_1: 0.9861 - val_true_positives_1: 2824.0000 - val_true_negatives_1: 3082.0000 - val_false_negatives_1: 185.0000 - val_false_positives_1: 129.0000
# Epoch 78/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0908 - acc: 0.9708 - recall_1: 0.9655 - precision_1: 0.9742 - auc_1: 0.9931 - true_positives_1: 11686.0000 - true_negatives_1: 12463.0000 - false_negatives_1: 417.0000 - false_positives_1: 310.0000 - val_loss: 0.1741 - val_acc: 0.9424 - val_recall_1: 0.9372 - val_precision_1: 0.9435 - val_auc_1: 0.9807 - val_true_positives_1: 2820.0000 - val_true_negatives_1: 3042.0000 - val_false_negatives_1: 189.0000 - val_false_positives_1: 169.0000
# Epoch 79/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.1080 - acc: 0.9614 - recall_1: 0.9612 - precision_1: 0.9596 - auc_1: 0.9916 - true_positives_1: 11634.0000 - true_negatives_1: 12283.0000 - false_negatives_1: 469.0000 - false_positives_1: 490.0000 - val_loss: 0.1778 - val_acc: 0.9386 - val_recall_1: 0.9455 - val_precision_1: 0.9288 - val_auc_1: 0.9798 - val_true_positives_1: 2845.0000 - val_true_negatives_1: 2993.0000 - val_false_negatives_1: 164.0000 - val_false_positives_1: 218.0000
# Epoch 80/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.0873 - acc: 0.9733 - recall_1: 0.9758 - precision_1: 0.9695 - auc_1: 0.9930 - true_positives_1: 11810.0000 - true_negatives_1: 12401.0000 - false_negatives_1: 293.0000 - false_positives_1: 372.0000 - val_loss: 0.1608 - val_acc: 0.9521 - val_recall_1: 0.9551 - val_precision_1: 0.9463 - val_auc_1: 0.9823 - val_true_positives_1: 2874.0000 - val_true_negatives_1: 3048.0000 - val_false_negatives_1: 135.0000 - val_false_positives_1: 163.0000
# Epoch 81/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0824 - acc: 0.9733 - recall_1: 0.9770 - precision_1: 0.9685 - auc_1: 0.9939 - true_positives_1: 11825.0000 - true_negatives_1: 12388.0000 - false_negatives_1: 278.0000 - false_positives_1: 385.0000 - val_loss: 0.1588 - val_acc: 0.9465 - val_recall_1: 0.9518 - val_precision_1: 0.9384 - val_auc_1: 0.9833 - val_true_positives_1: 2864.0000 - val_true_negatives_1: 3023.0000 - val_false_negatives_1: 145.0000 - val_false_positives_1: 188.0000
# Epoch 82/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0981 - acc: 0.9690 - recall_1: 0.9698 - precision_1: 0.9665 - auc_1: 0.9915 - true_positives_1: 11738.0000 - true_negatives_1: 12366.0000 - false_negatives_1: 365.0000 - false_positives_1: 407.0000 - val_loss: 0.3333 - val_acc: 0.8785 - val_recall_1: 0.9196 - val_precision_1: 0.8433 - val_auc_1: 0.9501 - val_true_positives_1: 2767.0000 - val_true_negatives_1: 2697.0000 - val_false_negatives_1: 242.0000 - val_false_positives_1: 514.0000
# Epoch 83/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.1378 - acc: 0.9528 - recall_1: 0.9509 - precision_1: 0.9521 - auc_1: 0.9861 - true_positives_1: 11509.0000 - true_negatives_1: 12194.0000 - false_negatives_1: 594.0000 - false_positives_1: 579.0000 - val_loss: 0.1667 - val_acc: 0.9437 - val_recall_1: 0.9359 - val_precision_1: 0.9472 - val_auc_1: 0.9823 - val_true_positives_1: 2816.0000 - val_true_negatives_1: 3054.0000 - val_false_negatives_1: 193.0000 - val_false_positives_1: 157.0000
# Epoch 84/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0951 - acc: 0.9692 - recall_1: 0.9697 - precision_1: 0.9671 - auc_1: 0.9929 - true_positives_1: 11736.0000 - true_negatives_1: 12374.0000 - false_negatives_1: 367.0000 - false_positives_1: 399.0000 - val_loss: 0.1581 - val_acc: 0.9441 - val_recall_1: 0.9232 - val_precision_1: 0.9596 - val_auc_1: 0.9846 - val_true_positives_1: 2778.0000 - val_true_negatives_1: 3094.0000 - val_false_negatives_1: 231.0000 - val_false_positives_1: 117.0000
# Epoch 85/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0880 - acc: 0.9715 - recall_1: 0.9670 - precision_1: 0.9744 - auc_1: 0.9939 - true_positives_1: 11703.0000 - true_negatives_1: 12465.0000 - false_negatives_1: 400.0000 - false_positives_1: 308.0000 - val_loss: 0.1862 - val_acc: 0.9365 - val_recall_1: 0.9525 - val_precision_1: 0.9192 - val_auc_1: 0.9812 - val_true_positives_1: 2866.0000 - val_true_negatives_1: 2959.0000 - val_false_negatives_1: 143.0000 - val_false_positives_1: 252.0000
# Epoch 86/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0976 - acc: 0.9682 - recall_1: 0.9688 - precision_1: 0.9660 - auc_1: 0.9924 - true_positives_1: 11725.0000 - true_negatives_1: 12360.0000 - false_negatives_1: 378.0000 - false_positives_1: 413.0000 - val_loss: 0.1692 - val_acc: 0.9453 - val_recall_1: 0.9568 - val_precision_1: 0.9320 - val_auc_1: 0.9823 - val_true_positives_1: 2879.0000 - val_true_negatives_1: 3001.0000 - val_false_negatives_1: 130.0000 - val_false_positives_1: 210.0000
# Epoch 87/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0816 - acc: 0.9741 - recall_1: 0.9760 - precision_1: 0.9709 - auc_1: 0.9941 - true_positives_1: 11813.0000 - true_negatives_1: 12419.0000 - false_negatives_1: 290.0000 - false_positives_1: 354.0000 - val_loss: 0.1754 - val_acc: 0.9399 - val_recall_1: 0.9408 - val_precision_1: 0.9352 - val_auc_1: 0.9809 - val_true_positives_1: 2831.0000 - val_true_negatives_1: 3015.0000 - val_false_negatives_1: 178.0000 - val_false_positives_1: 196.0000
# Epoch 88/100
# 389/389 [==============================] - 34s 87ms/step - loss: 0.1017 - acc: 0.9664 - recall_1: 0.9681 - precision_1: 0.9631 - auc_1: 0.9916 - true_positives_1: 11717.0000 - true_negatives_1: 12324.0000 - false_negatives_1: 386.0000 - false_positives_1: 449.0000 - val_loss: 0.1942 - val_acc: 0.9267 - val_recall_1: 0.8880 - val_precision_1: 0.9574 - val_auc_1: 0.9769 - val_true_positives_1: 2672.0000 - val_true_negatives_1: 3092.0000 - val_false_negatives_1: 337.0000 - val_false_positives_1: 119.0000
# Epoch 89/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.0925 - acc: 0.9696 - recall_1: 0.9644 - precision_1: 0.9730 - auc_1: 0.9932 - true_positives_1: 11672.0000 - true_negatives_1: 12449.0000 - false_negatives_1: 431.0000 - false_positives_1: 324.0000 - val_loss: 0.1930 - val_acc: 0.9315 - val_recall_1: 0.8980 - val_precision_1: 0.9578 - val_auc_1: 0.9781 - val_true_positives_1: 2702.0000 - val_true_negatives_1: 3092.0000 - val_false_negatives_1: 307.0000 - val_false_positives_1: 119.0000
# Epoch 90/100
# 389/389 [==============================] - 36s 91ms/step - loss: 0.0838 - acc: 0.9735 - recall_1: 0.9750 - precision_1: 0.9707 - auc_1: 0.9934 - true_positives_1: 11800.0000 - true_negatives_1: 12417.0000 - false_negatives_1: 303.0000 - false_positives_1: 356.0000 - val_loss: 0.1621 - val_acc: 0.9486 - val_recall_1: 0.9462 - val_precision_1: 0.9474 - val_auc_1: 0.9807 - val_true_positives_1: 2847.0000 - val_true_negatives_1: 3053.0000 - val_false_negatives_1: 162.0000 - val_false_positives_1: 158.0000
# Epoch 91/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0903 - acc: 0.9729 - recall_1: 0.9706 - precision_1: 0.9737 - auc_1: 0.9920 - true_positives_1: 11747.0000 - true_negatives_1: 12456.0000 - false_negatives_1: 356.0000 - false_positives_1: 317.0000 - val_loss: 0.2223 - val_acc: 0.9277 - val_recall_1: 0.9182 - val_precision_1: 0.9312 - val_auc_1: 0.9724 - val_true_positives_1: 2763.0000 - val_true_negatives_1: 3007.0000 - val_false_negatives_1: 246.0000 - val_false_positives_1: 204.0000
# Epoch 92/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0854 - acc: 0.9735 - recall_1: 0.9734 - precision_1: 0.9722 - auc_1: 0.9933 - true_positives_1: 11781.0000 - true_negatives_1: 12436.0000 - false_negatives_1: 322.0000 - false_positives_1: 337.0000 - val_loss: 0.1666 - val_acc: 0.9477 - val_recall_1: 0.9495 - val_precision_1: 0.9429 - val_auc_1: 0.9806 - val_true_positives_1: 2857.0000 - val_true_negatives_1: 3038.0000 - val_false_negatives_1: 152.0000 - val_false_positives_1: 173.0000
# Epoch 93/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0924 - acc: 0.9705 - recall_1: 0.9653 - precision_1: 0.9738 - auc_1: 0.9926 - true_positives_1: 11683.0000 - true_negatives_1: 12459.0000 - false_negatives_1: 420.0000 - false_positives_1: 314.0000 - val_loss: 0.1812 - val_acc: 0.9375 - val_recall_1: 0.9392 - val_precision_1: 0.9321 - val_auc_1: 0.9776 - val_true_positives_1: 2826.0000 - val_true_negatives_1: 3005.0000 - val_false_negatives_1: 183.0000 - val_false_positives_1: 206.0000
# Epoch 94/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0923 - acc: 0.9682 - recall_1: 0.9706 - precision_1: 0.9644 - auc_1: 0.9932 - true_positives_1: 11747.0000 - true_negatives_1: 12339.0000 - false_negatives_1: 356.0000 - false_positives_1: 434.0000 - val_loss: 0.1801 - val_acc: 0.9376 - val_recall_1: 0.9428 - val_precision_1: 0.9292 - val_auc_1: 0.9795 - val_true_positives_1: 2837.0000 - val_true_negatives_1: 2995.0000 - val_false_negatives_1: 172.0000 - val_false_positives_1: 216.0000
# Epoch 95/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0845 - acc: 0.9727 - recall_1: 0.9683 - precision_1: 0.9755 - auc_1: 0.9933 - true_positives_1: 11719.0000 - true_negatives_1: 12479.0000 - false_negatives_1: 384.0000 - false_positives_1: 294.0000 - val_loss: 0.1950 - val_acc: 0.9384 - val_recall_1: 0.9116 - val_precision_1: 0.9591 - val_auc_1: 0.9798 - val_true_positives_1: 2743.0000 - val_true_negatives_1: 3094.0000 - val_false_negatives_1: 266.0000 - val_false_positives_1: 117.0000
# Epoch 96/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.0930 - acc: 0.9721 - recall_1: 0.9669 - precision_1: 0.9756 - auc_1: 0.9917 - true_positives_1: 11702.0000 - true_negatives_1: 12480.0000 - false_negatives_1: 401.0000 - false_positives_1: 293.0000 - val_loss: 0.1822 - val_acc: 0.9428 - val_recall_1: 0.9548 - val_precision_1: 0.9289 - val_auc_1: 0.9809 - val_true_positives_1: 2873.0000 - val_true_negatives_1: 2991.0000 - val_false_negatives_1: 136.0000 - val_false_positives_1: 220.0000
# Epoch 97/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.0992 - acc: 0.9687 - recall_1: 0.9686 - precision_1: 0.9672 - auc_1: 0.9912 - true_positives_1: 11723.0000 - true_negatives_1: 12375.0000 - false_negatives_1: 380.0000 - false_positives_1: 398.0000 - val_loss: 0.2017 - val_acc: 0.9293 - val_recall_1: 0.9209 - val_precision_1: 0.9321 - val_auc_1: 0.9738 - val_true_positives_1: 2771.0000 - val_true_negatives_1: 3009.0000 - val_false_negatives_1: 238.0000 - val_false_positives_1: 202.0000
# Epoch 98/100
# 389/389 [==============================] - 34s 86ms/step - loss: 0.1099 - acc: 0.9625 - recall_1: 0.9665 - precision_1: 0.9568 - auc_1: 0.9892 - true_positives_1: 11698.0000 - true_negatives_1: 12245.0000 - false_negatives_1: 405.0000 - false_positives_1: 528.0000 - val_loss: 0.1759 - val_acc: 0.9407 - val_recall_1: 0.9462 - val_precision_1: 0.9322 - val_auc_1: 0.9786 - val_true_positives_1: 2847.0000 - val_true_negatives_1: 3004.0000 - val_false_negatives_1: 162.0000 - val_false_positives_1: 207.0000
# Epoch 99/100
# 389/389 [==============================] - 33s 86ms/step - loss: 0.1196 - acc: 0.9613 - recall_1: 0.9598 - precision_1: 0.9606 - auc_1: 0.9868 - true_positives_1: 11617.0000 - true_negatives_1: 12297.0000 - false_negatives_1: 486.0000 - false_positives_1: 476.0000 - val_loss: 0.2019 - val_acc: 0.9281 - val_recall_1: 0.9295 - val_precision_1: 0.9225 - val_auc_1: 0.9735 - val_true_positives_1: 2797.0000 - val_true_negatives_1: 2976.0000 - val_false_negatives_1: 212.0000 - val_false_positives_1: 235.0000
# Epoch 100/100
# 389/389 [==============================] - 35s 91ms/step - loss: 0.1177 - acc: 0.9592 - recall_1: 0.9581 - precision_1: 0.9580 - auc_1: 0.9889 - true_positives_1: 11596.0000 - true_negatives_1: 12265.0000 - false_negatives_1: 507.0000 - false_positives_1: 508.0000 - val_loss: 0.1883 - val_acc: 0.9389 - val_recall_1: 0.9339 - val_precision_1: 0.9395 - val_auc_1: 0.9771 - val_true_positives_1: 2810.0000 - val_true_negatives_1: 3030.0000 - val_false_negatives_1: 199.0000 - val_false_positives_1: 181.0000
